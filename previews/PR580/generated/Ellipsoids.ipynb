# %% [markdown]
# # Ellipsoids
#
#
# In this file, we will visit the basic features provided by Dionysos for manipulating ellipsoids:
# - inclusion
# - intersection
#
# First, let us import a few packages that are necessary to run this example.

# %%
using Dionysos
using StaticArrays
using LinearAlgebra
import LazySets
using Plots

# %% [markdown]
# The main package [Dionysos](https://github.com/dionysos-dev/Dionysos.jl) provides most important data structures that we will need.

# %%
const DI = Dionysos
const UT = DI.Utils
# Out:
# Dionysos.Utils

# %% [markdown]
# We define a plotting functions

# %%
function plot_config!(fig, El0, El, Elnew)
    if UT.is_included(Elnew, El0)
        plot!(fig, El0; color = :red, label = "El0")
        plot!(fig, Elnew; color = :green, label = "Elnew")
    else
        plot!(fig, Elnew; color = :green, label = "Elnew")
        plot!(fig, El0; color = :red, label = "El0")
    end
    return plot!(fig, El; color = :blue, label = "El", show = true)
end

function analyze(fig1, fig2, i)
    El0 = E0L[i]
    Elnew = UT.scale_for_inclusion_contact_point(El0, El)
    plot_config!(fig1, El0, El, Elnew)
    println(UT.is_included(El0, El) ? "El0 ⊆ El" : "El0 ⊈ El")

    Elnew = UT.scale_for_noninclusion_contact_point(El0, El)
    plot_config!(fig2, El0, El, Elnew)
    return println(!UT.is_disjoint(El0, El) ? "El0 ∩ El ≠ ∅" : "El0 ∩ El = ∅")
end
# Out:
# analyze (generic function with 1 method)

# %% [markdown]
# We define some ellipsoids. `LazySets.Ellipsoid(c, Q)` is the set
# `{x : (x−c)ᵀ Q⁻¹ (x−c) ≤ 1}` with shape matrix `Q`; to build it from the
# quadratic-form matrix `P` of `{x : (x−c)ᵀ P (x−c) ≤ 1}`, pass `Q = inv(P)`.

# %%
c = [1.5; 1.5]
P = [
    4.0 0.5
    0.5 6.0
]
El = LazySets.Ellipsoid(c, inv(P))

P0 = [
    0.4 -0.1
    -0.1 0.5
]
Q0 = inv(P0)
vals = [4.1, 3.32, 2.8, 2.4]
E0L = [LazySets.Ellipsoid([c0x; c0x - 0.2], Q0) for c0x in vals]
# Out:
# 4-element Vector{LazySets.EllipsoidModule.Ellipsoid{Float64, Vector{Float64}, Matrix{Float64}}}:
#  LazySets.EllipsoidModule.Ellipsoid{Float64, Vector{Float64}, Matrix{Float64}}([4.1, 3.8999999999999995], [2.6315789473684212 0.5263157894736842; 0.5263157894736842 2.1052631578947367])
#  LazySets.EllipsoidModule.Ellipsoid{Float64, Vector{Float64}, Matrix{Float64}}([3.32, 3.1199999999999997], [2.6315789473684212 0.5263157894736842; 0.5263157894736842 2.1052631578947367])
#  LazySets.EllipsoidModule.Ellipsoid{Float64, Vector{Float64}, Matrix{Float64}}([2.8, 2.5999999999999996], [2.6315789473684212 0.5263157894736842; 0.5263157894736842 2.1052631578947367])
#  LazySets.EllipsoidModule.Ellipsoid{Float64, Vector{Float64}, Matrix{Float64}}([2.4, 2.1999999999999997], [2.6315789473684212 0.5263157894736842; 0.5263157894736842 2.1052631578947367])

# %% [markdown]
# ### Case 1: non intersection

# %%
fig1_1 = plot(; aspect_ratio = :equal);
fig1_2 = plot(; aspect_ratio = :equal);
analyze(fig1_1, fig1_2, 1)
# Out:
# El0 ⊈ El
# El0 ∩ El = ∅

# %%
plot!(fig1_1)
# Out:
# Plot{Plots.GRBackend() n=3}

# %%
plot!(fig1_2)
# Out:
# Plot{Plots.GRBackend() n=3}

# %% [markdown]
# ### Case 2: non intersection

# %%
fig2_1 = plot(; aspect_ratio = :equal);
fig2_2 = plot(; aspect_ratio = :equal);
analyze(fig2_1, fig2_2, 2)
# Out:
# El0 ⊈ El
# El0 ∩ El = ∅

# %%
plot!(fig2_1)
# Out:
# Plot{Plots.GRBackend() n=3}

# %%
plot!(fig2_2)
# Out:
# Plot{Plots.GRBackend() n=3}

# %% [markdown]
# ### Case 3: intersection, non inclusion

# %%
fig3_1 = plot(; aspect_ratio = :equal);
fig3_2 = plot(; aspect_ratio = :equal);
analyze(fig3_1, fig3_2, 3)
# Out:
# El0 ⊈ El
# El0 ∩ El ≠ ∅

# %%
plot!(fig3_1)
# Out:
# Plot{Plots.GRBackend() n=3}

# %%
plot!(fig3_2)
# Out:
# Plot{Plots.GRBackend() n=3}

# %% [markdown]
# ### Case 4: inclusion

# %%
fig4_1 = plot(; aspect_ratio = :equal);
fig4_2 = plot(; aspect_ratio = :equal);
analyze(fig4_1, fig4_2, 4)
# Out:
# El0 ⊈ El
# El0 ∩ El ≠ ∅

# %%
plot!(fig4_1)
# Out:
# Plot{Plots.GRBackend() n=3}

# %%
plot!(fig4_2)
# Out:
# Plot{Plots.GRBackend() n=3}

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
